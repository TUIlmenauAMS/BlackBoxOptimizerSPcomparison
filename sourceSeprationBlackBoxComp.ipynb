# %% [markdown]
# <a href="https://colab.research.google.com/github/TUIlmenauAMS/BlackBoxOptimizerSPcomparison/blob/main/sourceSeprationBlackBoxComp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comparison  of Different Black Box Optimizers for Signal Processing Applications
# ## Source Separation, Recurrent Neural Network Optimization for Sound Generation
#
# Setup software:

# %%
#Setup software:
# %cd /content/
# !git clone https://github.com/TUIlmenauAMS/BlackBoxOptimizerSPcomparison
# %cd BlackBoxOptimizerSPcomparison
#download optimization of random directions, for 'optimrandomdir_parallel_linesearch':
# !wget https://raw.githubusercontent.com/TUIlmenauAMS/LowDelayMultichannelSourceSeparation_Random-Directions_Demo/main/optimrandomdir_parallel_linesearch.py
#Install pypop7 for comparison optimizers:
# !pip install pypop7
# Out:
# /content
# Cloning into 'BlackBoxOptimizerSPcomparison'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 45 (delta 17), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (45/45), 2.05 MiB | 11.53 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# /content/BlackBoxOptimizerSPcomparison
# --2023-09-11 14:29:24--  https://raw.githubusercontent.com/TUIlmenauAMS/LowDelayMultichannelSourceSeparation_Random-Directions_Demo/main/optimrandomdir_parallel_linesearch.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12776 (12K) [text/plain]
# Saving to: ‘optimrandomdir_parallel_linesearch.py’
#
# ...

# %% [markdown]
# ## Optimize the Source Separation

# %%
#Runs the source separation optimization
#Choose optimizers after line 366 in the following Python file
# %run ICAabskl_puredelay_multichan_randdir_online.py
# Out:
# X.shape= (115836, 2)
# Number of channels N: 2
# coeffs= [[0.33066639 0.8169565 ]
#  [0.18969832 0.51794078]
#  [0.69724523 0.72539442]
#  [0.21678538 0.61816089]]
# siglen= 115836
# blocks= 14
# Number of trials for initialization: 2**(N-1)= 2 , Number of mics: 2
# X0best= -0.4495066710489886
# optimizer= randdir
# coeffdeviation= 1.0
# coeffdeviation=ones
# num of CPU's or parallelset: 2
# Number of parallel processes, parallelset=  2
# endscale= 0.0
# m= 0 setfrac= 1.5 scale= 4.0
# lineexp= -1 X1= -0.744506155287929
# coeffdeviation= [[1.0549866  0.92950244]
#  [0.93456889 0.94472019]
#  [1.05898668 0.95930114]
#  [1.05189156 0.90702959]]
# Obj. function X0= -0.744506155287929 iteration m= 1 scale= 4.0 magvar.= 4.180110768829332
# coeffdeviation= [[0.96839793 0.9210853 ]
#  [0.92271924 0.90906082]
#  [0.97368463 0.88828432]
#  [0.97426667 1.06244288]]
# Obj. function X0= -1.3032311487112418 iteration m= 2 scale= 3.984016 magvar.= 3.7070475471114572
# ...

# %% [markdown]
# ## Optimize the Recurrent Neural Network

# %%
#Download used optimizer 'optimrandomdir_pytorch_parallel':
# !wget https://raw.githubusercontent.com/TUIlmenauAMS/RandomDirectionsForPytorch/main/optimrandomdir_pytorch_parallel.py
#Run RNN optimizer:
#Choose optimizer after line 214 in the following Python file
# %run pytorch_rnn_IIR.py
# Out:
# --2023-09-11 14:30:12--  https://raw.githubusercontent.com/TUIlmenauAMS/RandomDirectionsForPytorch/main/optimrandomdir_pytorch_parallel.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4018 (3.9K) [text/plain]
# Saving to: ‘optimrandomdir_pytorch_parallel.py’
#
# optimrandomdir_pyto 100%[===================>]   3.92K  --.-KB/s    in 0s
#
# 2023-09-11 14:30:12 (57.1 MB/s) - ‘optimrandomdir_pytorch_parallel.py’ saved [4018/4018]
#
# device= cpu
# frequency=  440.0
# k1, k2= 1.8798797763705424 -0.998001
# weights = OrderedDict([('rnn.weight_ih_l0', tensor([[1.],
#         [0.],
#         [0.]])), ('rnn.weight_hh_l0', tensor([[ 1.8799, -0.9980,  0.0000],
#         [ 1.0000,  0.0000,  0.0000],
# ...
